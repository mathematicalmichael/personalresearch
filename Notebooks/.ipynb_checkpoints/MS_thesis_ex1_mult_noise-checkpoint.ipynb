# %% [markdown]
# ## MS Example 1: Multiplicative Noise

# %%
import numpy as np
import dfo_v1 as dfo
import ECNoise as ECN
import active_subspaces as ac
import matplotlib.pyplot as plt

# %% [markdown]
# We choose $\mathbf{x}^{(0)}=(u,u,\ldots,u)$, $u \sim U[-1,1]$.

# %% [markdown]
# We let $t: \mathbf{x}: \mathbb{R}^{10} \to \mathbb{R}$, where $t(\mathbf{x})=100 \left(x_1^2+x_2^2+x_3^2\right)(1+ k\epsilon)$, where $\epsilon \sim N(0,1)$ so that $k\epsilon \sim N(0,k^2)$ and $L_1=200$.

# %%
dim=10
xinit=2*np.random.rand(dim,1)-1
print(np.shape(xinit))
print(np.transpose(xinit))
# Out:
# (10, 1)
# [[ 0.88063379 -0.1258937   0.87086008  0.11205288  0.65339731  0.0761168
#   -0.67323256  0.89325457  0.99396136 -0.83444258]]

# %%
k=1E-4
def tfun(x,var=k):
    y=np.copy(x)
    return (1e2*np.dot(np.transpose(y[0:3,:]),y[0:3,:]))*(1+(k**.5)*np.random.randn(1))
# Print check
print(tfun(xinit))
# Out:
# [[154.42045481]]

# %%
M=10 # number of ECNoise f evals

noise_array=ECN.ECNoise(tfun,xinit,M,mult=True)
mynoise=noise_array[0][0]
gen_f_vals=noise_array[2]
print(gen_f_vals, mynoise)
# Out:
# (10, 1) (10, 1)
# [153.9011186  155.70109893 156.13811007 155.66290047 155.83078192
#  154.62254268 154.16183978 163.40144185 160.38467944 158.23298725] 0.00014899153161002264

# %%
print('estimated noise var is', mynoise, 'true var is', k, 'with relative error', abs(mynoise-k)/k)
# Out:
# estimated noise var is 0.00014899153161002264 true var is 0.0001 with relative error 0.4899153161002264

# %%
x_b=np.copy(xinit)
#h=1E-2*np.linalg.norm(x_b,ord=np.inf)
h=0.1
fm=gen_f_vals[0]
f0=gen_f_vals[1]
fp=gen_f_vals[2]
L_1_hat=abs(fp-2*f0+fm)*(1/h**2)

d1=abs(fp-f0)*(1/h)
d2=abs(fm-f0)*(1/h)
L_1_hat_1=abs(d1-d2)*(1/h)


print('estimated upper bound on ||f''|| is', L_1_hat, 'estimated value of L_1 from FD is', L_1_hat_1)
# Out:
# estimated upper bound on ||f|| is 136.29691923851507 estimated value of L_1 from FD is 136.2969192385151

# %%
L_1_hat=196
mynoise=1e-4

#mu_star=dfo.get_mult_mu_star(mynoise,L_1_hat,dim)
#h=dfo.get_h(L_1_hat,dim)
mu_star_OG=dfo.get_mult_mu_star(mynoise,L_1_hat,dim)
h_OG=dfo.get_h(L_1_hat,dim)

# %%
x=np.copy(xinit)
maxit=100
xhist=np.array(x)
fhist=np.array(tfun(x))
yhist=xhist
ghist=fhist
L1Bhist=np.array(L_1_hat)
for i in range(maxit):
    [x,f,y,fy,p,q,L1B]=dfo.STARS(x,tfun,mu_star_OG,h_OG,mult=True)
    xhist=np.hstack((xhist,x))
    fhist=np.vstack((fhist,f))
    yhist=np.hstack((yhist,y))
    ghist=np.vstack((ghist,fy))
    L1Bhist=np.vstack((L1Bhist,L1B))

# %%
print('our algorithm terminates with x value',np.transpose(x), 'which has f value',f)
# Out:
# our algorithm terminates with x value [[ 1.17275940e-01  1.18707099e-03  1.33008901e-01  1.82446516e-01
#    7.51766286e-01  1.84627806e-01 -7.21431450e-01  7.48266937e-01
#    1.22559174e+00 -9.40827182e-01]] which has f value [[3.0989726]]

# %%
params = {'legend.fontsize': 40,
          'legend.handlelength': 3}
plt.rcParams["figure.figsize"] = (35,25)
plt.rcParams['figure.dpi'] = 80
plt.rcParams['savefig.dpi'] = 100
plt.rcParams['font.size'] = 60
plt.rcParams['figure.titlesize'] = 'xx-large'
plt.rcParams.update(params)



plt.semilogy(fhist,lw=6,label='STARS, full vars')
plt.legend()
plt.show()

# %%
ss = ac.subspaces.Subspaces()
mu_star=dfo.get_mult_mu_star(mynoise,L_1_hat,3)
h=dfo.get_h(L_1_hat,3)

for tr_stop in range(40,100,20):

    trainx=np.hstack((xhist[:,0:tr_stop],yhist[:,0:tr_stop]))
    trainf=np.vstack((fhist[0:tr_stop],ghist[0:tr_stop]))
    trainx=np.transpose(trainx)
    

    # Use Local Linears
    df = ac.gradients.local_linear_gradients(trainx, trainf) #Estimated gradients using local linear models
    ss.compute(df=df, nboot=0)
    
    # Use Global Quadratic
    #ss.compute(X=trainx, f=trainf, nboot=0, sstype='QPHD')

    sub=ss.eigenvecs[:,0:3]
    
    our_wts=np.sqrt(ss.eigenvals)
    print(our_wts)
    
    print(sub)
    
    x4=np.transpose([xhist[:,tr_stop]])
    xhist4=np.array(x4)
    fhist4=np.array(tfun(x4))


    for i in range(0,100-tr_stop):
        [x4,f,temp,temp2,p,q,L1B]=dfo.STARS(x4,tfun,mu_star,h,active=sub, wts=None, mult=True)
        xhist4=np.hstack((xhist4,x4))
        fhist4=np.vstack((fhist4,f))
    plt.semilogy(range(tr_stop,101),fhist4,label='Train '+str(tr_stop),lw=6)


plt.semilogy(fhist, ls=':', lw=6, label='STARS full vars')

plt.xlabel('$k$, iteration count')
plt.ylabel('$\log f(\lambda^{(k)})$')
plt.title('Example 1: Learning the AS from STARS iteartes')
plt.legend()
plt.show()

print(trainf.shape)
# Out:
# n should be an integer. Performing conversion.
# [[9.32836451e+04]
#  [4.25419671e+03]
#  [2.17873799e+03]
#  [1.45683165e+03]
#  [7.55199949e+02]
#  [5.30054317e+02]
#  [3.53418182e+02]
#  [1.49861513e+02]
#  [1.17496311e+02]
#  [6.42599435e+01]]
# [[ 0.22539984  0.07672501  0.57956809]
#  [ 0.07461987  0.25541425 -0.38699512]
#  [-0.45148062  0.27608403  0.52972749]
#  [-0.20567261 -0.75519812  0.11581369]
#  [-0.08827757 -0.0817042  -0.2458662 ]
#  [-0.49303105  0.39317014 -0.18855457]
#  [-0.14118727 -0.25834378 -0.30369189]
#  [ 0.54135979  0.15084538 -0.079224  ]
#  [-0.36413906  0.01150121 -0.13544692]
#  [-0.0318865  -0.17732396  0.0863568 ]]
# n should be an integer. Performing conversion.
# [[1.07458361e+05]
#  [4.53031207e+03]
#  [7.51553194e+02]
#  [6.69895209e+02]
#  [3.45468451e+02]
#  [2.48784143e+02]
#  [1.97538558e+02]
#  [1.12271566e+02]
#  [6.55689106e+01]
#  [4.50768272e+01]]
# [[ 0.2256626   0.212799    0.09577856]
#  [ 0.07435027  0.19981418  0.36170126]
#  [-0.45131256  0.38195876  0.1146803 ]
#  [-0.20531307 -0.70864374  0.21745024]
#  [-0.08836201 -0.13483911  0.02690285]
#  [-0.49325959  0.36228181  0.18716564]
#  [-0.14121347 -0.28294846  0.30759511]
#  [ 0.54129887  0.16723983  0.54739839]
#  [-0.36420607  0.00750133  0.25468125]
#  [-0.03173802 -0.09595557  0.55198321]]
# n should be an integer. Performing conversion.
# [[65798.74692021]
#  [ 3927.59749076]
#  [  682.21913808]
#  [  651.28666572]
#  [  555.45789556]
#  [  380.23892546]
#  [  269.26171777]
#  [  213.94275987]
#  [  162.29223654]
#  [  106.83328931]]
# [[ 0.22601916  0.21217156  0.06694967]
#  [ 0.07469987  0.20471884  0.32458227]
#  [-0.45069519  0.37413768 -0.18444185]
#  [-0.20653373 -0.70903851 -0.08053832]
#  [-0.08858981 -0.13692206  0.09063345]
#  [-0.49263777  0.36879293  0.29035458]
#  [-0.1416857  -0.28107552  0.52468844]
#  [ 0.54156487  0.16193029  0.28500782]
#  [-0.36418176  0.00625276  0.13274369]
#  [-0.03189208 -0.10168076  0.61886215]]
# (160, 1)

# %%
plt.plot(xhist[0],lw=6,label='Values of $\lambda_1$ for STARS iterates (full variables)')
plt.xlabel('$k$, iteration count')
plt.ylabel('$\lambda^{(k)}_1$')
plt.title('Example 1: STARS and ASTARS Convergence')
plt.legend()

# %%
mu_star=dfo.get_mult_mu_star(mynoise,L_1_hat,3)
h=dfo.get_h(L_1_hat,3)


x3=np.copy(xinit)
xhist3=np.array(x3)
fhist3=np.array(tfun(x3))
active=np.eye(dim)
active=np.transpose(active[0:3,:])
eigenvals=np.zeros((dim,1))
for i in range(3):
    eigenvals[i]=1


for i in range(50):
    [x3,f,temp1,temp2, p ,q,L1B]=dfo.STARS(x3,tfun,mu_star,h,active=active,mult=True,wts=None)
    xhist3=np.hstack((xhist3,x3))
    fhist3=np.vstack((fhist3,f))
    
plt.semilogy(fhist3,lw=6, label='active stars with true active vars')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15,10))
ss = ac.subspaces.Subspaces()
mu_star=dfo.get_mult_mu_star(mynoise,L_1_hat,3)
h=dfo.get_h(L_1_hat,3)

tr_stop=20

trainx=np.hstack((xhist[:,0:tr_stop],yhist[:,0:tr_stop]))
trainf=np.vstack((fhist[0:tr_stop],ghist[0:tr_stop]))
trainx=np.transpose(trainx)

# Use Local Linears
df = ac.gradients.local_linear_gradients(trainx, trainf) #Estimated gradients using local linear models
ss.compute(df=df, nboot=0)

# Use Global Quadratic
#ss.compute(X=trainx, f=trainf, nboot=0, sstype='QPHD')

sub=ss.eigenvecs[:,0:3]
our_wts=np.sqrt(ss.eigenvals)
print(our_wts)

print(sub)
 
x4=np.transpose([xhist[:,tr_stop]])
xhist4=np.array(x4)
fhist5=np.vstack((fhist[0:tr_stop],tfun(x4)))


for i in range(0,50-tr_stop):
    [x4,f,temp,temp2,p,q,L1B]=dfo.STARS(x4,tfun,mu_star,h,active=sub,wts=None, mult=True)
    xhist4=np.hstack((xhist4,x4))
    fhist5=np.vstack((fhist5,f))
    #plt.semilogy(range(tr_stop,301),fhist4,label='Train '+str(tr_stop))


plt.semilogy(fhist5,lw=6, label='active stars on 35 training points')
plt.legend()
plt.show()
# Out:
# n should be an integer. Performing conversion.
# [[1.32615422e+05]
#  [2.96776363e+02]
#  [1.98629428e+02]
#  [9.44095186e+01]
#  [5.90643217e+01]
#  [3.79586095e+01]
#  [2.84263790e+01]
#  [1.89323869e+01]
#  [1.04151356e+01]
#  [4.54210493e+00]]
# [[ 2.25305958e-01  3.45886559e-02  5.74672430e-01]
#  [ 7.40017111e-02  2.32134709e-01 -7.21062444e-02]
#  [-4.51962436e-01  8.07262941e-02  7.35931186e-01]
#  [-2.04113198e-01 -4.36871406e-01 -5.02501825e-02]
#  [-8.81349578e-02  2.81507382e-01 -6.73555681e-02]
#  [-4.93875691e-01  1.51077711e-02  6.18546718e-04]
#  [-1.40739134e-01  5.85911159e-01 -1.83217779e-01]
#  [ 5.40998416e-01  2.68413678e-01  2.79199894e-01]
#  [-3.64228460e-01  2.59536253e-01 -3.85871308e-02]
#  [-3.16006403e-02  4.30548761e-01 -5.37125584e-02]]

# %%
stars_full, sf_ls = 'red', '--'
active_stars_learned, lr_ls = 'black', '-.'
active_stars_ref, rf_ls = 'blue', ':'

plt.xlabel('$k$, iteration count')
plt.ylabel('$\log f(\lambda^{(k)})$')
plt.title('Example 1: STARS and ASTARS Convergence')

plt.semilogy(fhist[0:50], lw=9, ls=sf_ls, color=stars_full, label='STARS, full vars with learned hyperparams')
plt.semilogy(fhist3, lw=9, ls=rf_ls, color=active_stars_ref,  label='Active STARS, true active vars with learned hyperparams')
plt.semilogy(fhist5[0:50], lw=9, ls=lr_ls, color=active_stars_learned,label='Active STARS, learned active vars with learned hyperparams')

plt.legend()
plt.show()

# %%
fhist=fhist[0:51]
print(fhist[50],fhist3[50],fhist5[50],fhist.shape,fhist3.shape,fhist5.shape)
# Out:
# [21.44549376] [4.46795054] [7.71274171] (51, 1) (51, 1) (51, 1)

# %%
fac=10

FHIST=np.copy(fhist)
FHIST3=np.copy(fhist3)
FHIST5=np.copy(fhist5)
FHIST5_mu=np.zeros((51,0))

sim_n=100

for j in range(sim_n):
    
    
    
    x=np.copy(xinit)
    maxit=50
    xhist=np.array(x)
    fhist=np.array(tfun(x))
    yhist=xhist
    ghist=fhist

    for i in range(maxit):
        [x,f,y,fy,p,q,L1B]=dfo.STARS(x,tfun,mu_star_OG,h_OG,mult=True)
        xhist=np.hstack((xhist,x))
        fhist=np.vstack((fhist,f))
        yhist=np.hstack((yhist,y))
        ghist=np.vstack((ghist,fy))
        
    #yhist=yhist[:,1:]
    #ghist=ghist[:,1:]
        
    x=np.copy(xinit)
    maxit=50
    xhist_mu=np.array(x)
    fhist_mu=np.array(tfun(x))
    yhist_mu=xhist_mu
    ghist_mu=fhist_mu

    for i in range(maxit):
        [x,f,y,fy,p,q,L1B]=dfo.STARS(x,tfun,fac*mu_star_OG,h_OG,mult=True)
        xhist_mu=np.hstack((xhist_mu,x))
        fhist_mu=np.vstack((fhist_mu,f))
        yhist_mu=np.hstack((yhist_mu,y))
        ghist_mu=np.vstack((ghist_mu,fy))
        
    
    #yhist_mu=yhist_mu[:,1:]
    #ghist_mu=ghist[:,1:]

    mu_star=dfo.get_mu_star(mynoise,L_1_hat,3)
    h=dfo.get_h(L_1_hat,3)


    x3=np.copy(xinit)
    xhist3=np.array(x3)
    fhist3=np.array(tfun(x3))
    active=np.eye(dim)
    active=np.transpose(active[0:3,:])


    for i in range(50):
        [x3,f,temp1,temp2, p ,q,L1B]=dfo.STARS(x3,tfun,mu_star,h,active=active,mult=True)
        xhist3=np.hstack((xhist3,x3))
        fhist3=np.vstack((fhist3,f))



    ss = ac.subspaces.Subspaces()
    mu_star=dfo.get_mult_mu_star(mynoise,L_1_hat,3)
    h=dfo.get_h(L_1_hat,3)

    tr_stop=20

    trainx=np.hstack((xhist[:,0:tr_stop],yhist[:,0:tr_stop]))
    trainf=np.vstack((fhist[0:tr_stop],ghist[0:tr_stop]))
    trainx=np.transpose(trainx)

    # Use Local Linears
    df = ac.gradients.local_linear_gradients(trainx, trainf) #Estimated gradients using local linear models
    ss.compute(df=df, nboot=0)

    # Use Global Quadratic
    #ss.compute(X=trainx, f=trainf, nboot=0, sstype='QPHD')

    sub=ss.eigenvecs[:,0:3]

    x4=np.transpose([xhist[:,tr_stop]])
    xhist4=np.array(x4)
    fhist5=np.vstack((fhist[0:tr_stop],tfun(x4)))


    for i in range(0,50-tr_stop):
        [x4,f,temp,temp2,p,q,L1B]=dfo.STARS(x4,tfun,mu_star,h,active=sub,wts=None, mult=True)
        xhist4=np.hstack((xhist4,x4))
        fhist5=np.vstack((fhist5,f))
        
    tr_stop=20

    trainx=np.hstack((xhist_mu[:,0:tr_stop],yhist_mu[:,0:tr_stop]))
    trainf=np.vstack((fhist_mu[0:tr_stop],ghist_mu[0:tr_stop]))
    trainx=np.transpose(trainx)

    # Use Local Linears
    df = ac.gradients.local_linear_gradients(trainx, trainf) #Estimated gradients using local linear models
    ss.compute(df=df, nboot=0)

    # Use Global Quadratic
    #ss.compute(X=trainx, f=trainf, nboot=0, sstype='QPHD')

    sub=ss.eigenvecs[:,0:3]

    x4=np.transpose([xhist_mu[:,tr_stop]])
    xhist4_mu=np.array(x4)
    fhist5_mu=np.vstack((fhist_mu[0:tr_stop],tfun(x4)))


    for i in range(0,50-tr_stop):
        [x4,f,temp,temp2,p,q,L1B]=dfo.STARS(x4,tfun,mu_star,h,active=sub,wts=None, mult=True)
        xhist4_mu=np.hstack((xhist4_mu,x4))
        fhist5_mu=np.vstack((fhist5_mu,f))
        

    #print(FHIST5.shape,fhist5.shape)
    FHIST=np.hstack((FHIST,fhist))
    FHIST3=np.hstack((FHIST3,fhist3))
    FHIST5=np.hstack((FHIST5,fhist5))
    FHIST5_mu=np.hstack((FHIST5_mu,fhist5_mu))
   
FHIST5_mu=FHIST5_mu[:,1:]

print(FHIST.shape,FHIST3.shape,FHIST5.shape, FHIST5_mu.shape)
# Out:
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# n should be an integer. Performing conversion.
# (51, 101) (51, 101) (51, 101) (51, 99)

# %%
stars_full, sf_ls = 'red', '--'
active_stars_learned, lr_ls = 'black', '-.'
active_stars_learned_mu, lrmu_ls = 'gray', '-.'
active_stars_ref, rf_ls = 'blue', ':'

alpha=0.3

for j in range(sim_n):
    plt.semilogy(FHIST[0:50,j], lw=5, alpha=alpha,color=stars_full, ls=sf_ls)
    plt.semilogy(FHIST3[0:50,j], lw=5, alpha=alpha,color=active_stars_ref ,ls=rf_ls)
    #plt.semilogy(FHIST5[0:50,j], lw=5, alpha=alpha,color=active_stars_learned, ls=lr_ls)
plt.semilogy(FHIST[0:50,j], lw=5, alpha=alpha,color=stars_full,ls=sf_ls, label='STARS, full vars with learned hyperparams')
plt.semilogy(FHIST3[0:50,j], lw=5, alpha=alpha,color=active_stars_ref ,ls=rf_ls,  label='Active STARS, true active vars with learned hyperparams')
#plt.semilogy(FHIST5[0:50,j], lw=5, alpha=alpha,color=active_stars_learned, ls=lr_ls, label='Active STARS, learned active vars with learned hyperparams')

plt.xlabel('$k$, iteration count')
plt.ylabel('$\log f(\lambda^{(k)})$')
plt.title('Example 1: STARS and ASTARS Convergence Sensitivity Analysis')

params = {'legend.fontsize': 40,
          'legend.handlelength': 3}
plt.rcParams["figure.figsize"] = (35,20)
plt.rcParams['figure.dpi'] = 80
plt.rcParams['savefig.dpi'] = 100
plt.rcParams['font.size'] = 60
plt.rcParams['figure.titlesize'] = 'xx-large'
plt.rcParams.update(params)
plt.legend()
plt.show()

# %%
FHISTA=np.zeros((50,1))
FHISTA3=np.zeros((50,1))
FHISTA5=np.zeros((50,1))
FHISTA5_mu=np.zeros((50,1))

for j in range(50):
    FHISTA[j]=np.sum(FHIST[j,:],axis=0)/sim_n
    FHISTA3[j]=np.sum(FHIST3[j,:],axis=0)/sim_n
    FHISTA5[j]=np.sum(FHIST5[j,:],axis=0)/sim_n
    FHISTA5_mu[j]=np.sum(FHIST5_mu[j,:],axis=0)/sim_n
    


plt.semilogy(FHISTA, lw=10, alpha=1,color=stars_full,ls=sf_ls, label='STARS, full vars, learned hyperparams')
plt.semilogy(FHISTA3, lw=10, alpha=1,color=active_stars_ref ,ls=rf_ls,  label='Active STARS, true active vars, learned hyperparams')
plt.semilogy(FHISTA5, lw=10, alpha=1,color=active_stars_learned, ls=lr_ls, label='Active STARS, learned active vars, learned hyperparams')
plt.semilogy(FHISTA5_mu, lw=10, alpha=1,color=active_stars_learned_mu, ls=lrmu_ls, label='Active STARS, learned active vars, learned hyperparams, $10\cdot \mu^*$')

plt.xlabel('$k$, iteration count')
plt.ylabel('$\log f(\lambda^{(k)})$')
plt.title('Example 1: STARS and ASTARS Convergence, Averaged Results')

params = {'legend.fontsize': 40,
          'legend.handlelength': 3}
plt.rcParams["figure.figsize"] = (35,20)
plt.rcParams['figure.dpi'] = 80
plt.rcParams['savefig.dpi'] = 100
plt.rcParams['font.size'] = 60
plt.rcParams['figure.titlesize'] = 'xx-large'
plt.rcParams.update(params)
plt.legend()
plt.show()
